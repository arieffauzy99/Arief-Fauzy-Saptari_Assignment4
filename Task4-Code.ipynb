# %%
print("hello world")
# Out:
# hello world

# %%
pip install folium
pip install matplotlib seaborn numpy shapely
# Out:
#   Cell In[2], line 1
#     pip install folium
#         ^
# SyntaxError: invalid syntax

# %%
pip install matplotlib seaborn numpy shapely
# Out:
# Collecting matplotlib
#   Using cached matplotlib-3.10.8-cp311-cp311-win_amd64.whl.metadata (52 kB)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy in e:\mapid 2026\day 4 mulai pyton awal\mapid_webgis_day4\lib\site-packages (2.4.1)
# Requirement already satisfied: shapely in e:\mapid 2026\day 4 mulai pyton awal\mapid_webgis_day4\lib\site-packages (2.1.2)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.3.3-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.61.1-cp311-cp311-win_amd64.whl.metadata (116 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.9-cp311-cp311-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in e:\mapid 2026\day 4 mulai pyton awal\mapid_webgis_day4\lib\site-packages (from matplotlib) (26.0)
# Collecting pillow>=8 (from matplotlib)
#   Using cached pillow-12.1.0-cp311-cp311-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Using cached pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in e:\mapid 2026\day 4 mulai pyton awal\mapid_webgis_day4\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pandas>=1.2 in e:\mapid 2026\day 4 mulai pyton awal\mapid_webgis_day4\lib\site-packages (from seaborn) (3.0.0)
# Requirement already satisfied: tzdata in e:\mapid 2026\day 4 mulai pyton awal\mapid_webgis_day4\lib\site-packages (from pandas>=1.2->seaborn) (2025.3)
# Requirement already satisfied: six>=1.5 in e:\mapid 2026\day 4 mulai pyton awal\mapid_webgis_day4\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Using cached matplotlib-3.10.8-cp311-cp311-win_amd64.whl (8.1 MB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached contourpy-1.3.3-cp311-cp311-win_amd64.whl (225 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.61.1-cp311-cp311-win_amd64.whl (2.3 MB)
# Using cached kiwisolver-1.4.9-cp311-cp311-win_amd64.whl (73 kB)
# Using cached pillow-12.1.0-cp311-cp311-win_amd64.whl (7.0 MB)
# Using cached pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib, seaborn
#
#    ---------------------------------------- 0/8 [pyparsing]
#    ---------------------------------------- 0/8 [pyparsing]
#    ---------------------------------------- 0/8 [pyparsing]
#    ---------------------------------------- 0/8 [pyparsing]
#    ---------------------------------------- 0/8 [pyparsing]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ----- ---------------------------------- 1/8 [pillow]
#    ---------- ----------------------------- 2/8 [kiwisolver]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    --------------- ------------------------ 3/8 [fonttools]
#    -------------------- ------------------- 4/8 [cycler]
#    -------------------- ------------------- 4/8 [cycler]
#    ------------------------- -------------- 5/8 [contourpy]
#    ------------------------- -------------- 5/8 [contourpy]
#    ------------------------- -------------- 5/8 [contourpy]
#    ------------------------- -------------- 5/8 [contourpy]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ------------------------------ --------- 6/8 [matplotlib]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ----------------------------------- ---- 7/8 [seaborn]
#    ---------------------------------------- 8/8 [seaborn]
#
# Successfully installed contourpy cycler fonttools kiwisolver matplotlib pillow pyparsing seaborn
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Hands on day 1
# 1. Import Libray Pyhton yang sudah diinstal di terminal

# %%
import pandas as pd
import geopandas as gpd
import folium
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
import geopandas as gpd

geojson_path = r"E:\MAPID 2026\Day 4 Mulai Pyton Awal\Mapid_Webgis_Day4\labs\data_dummy_hidrokarbon.geojson"

gdf_geojson = gpd.read_file(geojson_path)
print(gdf_geojson.head())

# 4. Hitung centroid polygon
gdf_geojson["centroid"] = gdf_geojson.geometry.centroid

# 5. Ambil koordinat longitude & latitude
gdf_geojson["longitude"] = gdf_geojson["centroid"].x
gdf_geojson["latitude"] = gdf_geojson["centroid"].y

# 6. Buat DataFrame analisis (salinan)
df_hidrokarbon = gdf_geojson.copy()

# 7. Tampilkan hasil
print(df_hidrokarbon[["longitude", "latitude"]].head())

# 8. Selanjut Statistik deskriptif seluruh parameter numerik

print("Statistik Deskriptif:")

print(df_hidrokarbon.describe())

#9. Membuat canvas plot dengan ukuran 8x4
plt.figure(figsize=(8, 4))

# 2. Membuat histogram distribusi data
# bins=8 membagi data ke 8 batang, kde=True menambahkan garis tren
sns.histplot(df_hidrokarbon['potensi_hidrokarbon'], bins=8, kde=True, color='teal')

# 3. Menambahkan Judul dan Label Sumbu
plt.title('Distribusi Potensi Hidrokarbon (Juta Barrel) Jawa Barat')
plt.xlabel('Potensi Hidrokarbon (Juta Barel)')
plt.ylabel('Jumlah Wilayah Terindikasi')

# 4. Merapikan layout agar tidak terpotong
plt.tight_layout()

# 5. Menampilkan plot
plt.show()
# Out:
#      wilayah  potensi_hidrokarbon  kedalaman jenis_batuan  porositas  \
# 0    Cirebon                  120       2500    Sandstone         18
# 1     Bekasi                  200       3200    Limestone         22
# 2   Karawang                  150       2800        Shale         15
# 3     Subang                   80       2100    Sandstone         20
# 4  Indramayu                  170       3000        Shale         17
#
#    permeabilitas kecamatan                                           geometry
# 0            120    Kec. A  POLYGON ((108.5 -6.7, 108.6 -6.7, 108.6 -6.6, ...
# 1            210    Kec. B  POLYGON ((107 -6.3, 107.1 -6.3, 107.1 -6.2, 10...
# 2             90    Kec. C  POLYGON ((107.3 -6.2, 107.4 -6.2, 107.4 -6.1, ...
# 3            160    Kec. D  POLYGON ((107.7 -6.5, 107.8 -6.5, 107.8 -6.4, ...
# 4            130    Kec. E  POLYGON ((108 -6.4, 108.1 -6.4, 108.1 -6.3, 10...
#    longitude  latitude
# 0     108.55     -6.65
# 1     107.05     -6.25
# 2     107.35     -6.15
# 3     107.75     -6.45
# 4     108.05     -6.35
# Statistik Deskriptif:
#        potensi_hidrokarbon    kedalaman  porositas  permeabilitas   longitude  \
# count            10.000000    10.000000  10.000000      10.000000   10.000000
# mean            119.000000  2530.000000  18.000000     125.500000  107.740000
# std              44.522154   424.394994   2.581989      37.892391    0.477144
# min              60.000000  1800.000000  14.000000      80.000000  107.050000
# 25%              83.750000  2250.000000  16.250000     102.500000  107.400000
# 50%             115.000000  2550.000000  18.000000     117.500000  107.700000
# 75%             145.000000  2775.000000  19.750000     137.500000  108.000000
# max             200.000000  3200.000000  22.000000     210.000000  108.550000
#
#         latitude
# count  10.000000
# mean   -6.560000
# std     0.268535
# min    -6.950000
# 25%    -6.750000
# 50%    -6.550000
# 75%    -6.375000
# max    -6.150000
# C:\Users\ojiar\AppData\Local\Temp\ipykernel_63620\2140118084.py:9: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf_geojson["centroid"] = gdf_geojson.geometry.centroid

# %%
import pandas as pd
import geopandas as gpd
import folium
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# 1. Load Data Geojson
import geopandas as gpd

geojson_path = r"E:\MAPID 2026\Day 4 Mulai Pyton Awal\Mapid_Webgis_Day4\labs\data_point_pluvial_flood_dataset.geojson"

# 2. Buat DataFrame analisis (salinan)
df_banjir = gdf_geojson.copy()

# 3. Load data flood dan Tampilkan 5 Baris Pertama data floodnya
gdf_geojson = gpd.read_file(geojson_path)
print(gdf_geojson.head())

# 4. Buat DataFrame analisis (salinan)
df_banjir = gdf_geojson.copy()

# 5. Eksplorasi Data
print("Statistik Deskriptif:")

print(df_banjir.info)
print(df_banjir.describe())

# 6. Membuat figure dengan 2 subplots (1 baris, 2 kolom)
plt.figure(figsize=(12, 5))

# a. Histogram untuk parameter Slope
plt.subplot(1, 2, 1)
sns.histplot(df_banjir['Slope'], kde=True, color='teal')
plt.title('Distribusi Parameter Slope')
plt.xlabel('Slope')
plt.ylabel('Frekuensi')

# b. Histogram untuk parameter Rainfall
plt.subplot(1, 2, 2)
sns.histplot(df_banjir['Rainfall'], kde=True, color='blue')
plt.title('Distribusi Parameter Rainfall')
plt.xlabel('Rainfall')
plt.ylabel('Frekuensi')

plt.tight_layout()
plt.show()

# 7. Analisis sebaran kategori susceptibility (SUSCEP) pada dataset
jumlah_suscep = df_banjir['SUSCEP'].value_counts()
print("Jumlah titik per kategori Susceptibility:")
print(jumlah_suscep)

# 8. Memunculkan grafik susce[]
plt.figure(figsize=(10, 6))
sns.countplot(data=df_banjir, x='SUSCEP', palette='viridis')
plt.title('Sebaran Kategori Susceptibility (SUSCEP)')
plt.xlabel('Kategori Susceptibility')
plt.ylabel('Jumlah Titik')

plt.show()

# 9. Scatter Plot Hubungan Parameter
plt.figure(figsize=(10, 6))
# a. Membuat scatter plot antara Slope dan Rainfall
sns.scatterplot(data=df_banjir, x='Slope', y='Rainfall', hue='SUSCEP', palette='magma')
plt.title('Hubungan antara Slope dan Rainfall')
plt.xlabel('Slope')
plt.ylabel('Rainfall')
plt.legend(title='Susceptibility', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# 10. Menghitung matriks korelasi
# Kita hanya mengambil kolom numerik agar tidak error saat menghitung korelasi
kolom_numerik = df_banjir.select_dtypes(include=['float64', 'int64'])
korelasi_matriks = kolom_numerik.corr()

plt.figure(figsize=(10, 8))
sns.heatmap(korelasi_matriks, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)

plt.title('Heatmap Korelasi Antar Parameter Numerik')
plt.show()

# 11. Membuat Peta Interaktif
# Memilih dan filter 5 titik acak dari dataset
# Gunakan .sample(n) sesuai hint untuk mengambil data acak
df_sample = df_banjir.sample(n=5)

# Membuat objek peta dasar
# Kita ambil rata-rata koordinat dari data sampel sebagai titik tengah peta
m = folium.Map(location=[df_sample['Y'].mean(), df_sample['X'].mean()], zoom_start=12)

# Menambahkan marker untuk setiap titik hasil filter
for index, row in df_sample.iterrows():
    # Menyiapkan teks popup yang menampilkan Susceptibility, Slope, Rainfall, dan TWI
    popup_text = f"Susceptibility: {row['SUSCEP']}<br>" \
                 f"Slope: {row['Slope']}<br>" \
                 f"Rainfall: {row['Rainfall']}<br>" \
                 f"TWI: {row['TWI']}"
    
    # Membuat marker dengan popup
    folium.Marker(
        location=[row['Y'], row['X']],
        popup=folium.Popup(popup_text, max_width=300),
        tooltip=row['SUSCEP']
    ).add_to(m)

    # 4. Simpan peta sebagai file HTML
m.save('peta_titik_flood.html')
# Out:
#           X         Y      Slope    Curvature       Aspect       TWI     FA  \
# 0  3.909444  7.443056  46.686142 -3.888000e+09   45.000000 -3.250368  147.0
# 1  3.908611  7.442778  52.151768  1.296000e+09   60.945396 -4.313832   61.0
# 2  3.908889  7.442778  66.484085  0.000000e+00   67.619865 -8.327622    1.0
# 3  3.909167  7.442778  58.007183 -2.592000e+09   38.659809 -4.707937   51.0
# 4  3.909444  7.442778  60.503792 -1.296000e+09  351.869904 -5.985817   15.0
#
#    Drainage    Rainfall     SUSCEP                 geometry
# 0  228.8528  101.515616  Very_High  POINT (3.90944 7.44306)
# 1  229.6781   80.409863  Very_High  POINT (3.90861 7.44278)
# 2  230.5920   78.986849  Very_High  POINT (3.90889 7.44278)
# 3  235.4210   81.953151  Very_High  POINT (3.90917 7.44278)
# 4  234.4346   85.866027  Very_High  POINT (3.90944 7.44278)
# Statistik Deskriptif:
# <bound method DataFrame.info of                X         Y      Slope    Curvature       Aspect       TWI  \
# 0       3.909444  7.443056  46.686142 -3.888000e+09   45.000000 -3.250368
# 1       3.908611  7.442778  52.151768  1.296000e+09   60.945396 -4.313832
# 2       3.908889  7.442778  66.484085  0.000000e+00   67.619865 -8.327622
# 3       3.909167  7.442778  58.007183 -2.592000e+09   38.659809 -4.707937
# 4       3.909444  7.442778  60.503792 -1.296000e+09  351.869904 -5.985817
# ...          ...       ...        ...           ...         ...       ...
# 144396  3.864167  7.311667  70.837776  1.296000e+09  272.489563 -8.552538
# 144397  3.864444  7.311667  72.578880  1.296000e+09  295.559967 -9.347733
# 144398  3.864722  7.311667  70.667946  6.480000e+09  322.125031 -9.236161
# 144399  3.859722  7.311389  61.980232  1.296000e+09  183.814072 -8.819514
# 144400  3.860000  7.311389  68.768135  5.184000e+09  150.945389 -9.134113
#
#            FA  Drainage    Rainfall     SUSCEP                 geometry
# 0       147.0  228.8528  101.515616  Very_High  POINT (3.90944 7.44306)
# 1        61.0  229.6781   80.409863  Very_High  POINT (3.90861 7.44278)
# 2         1.0  230.5920   78.986849  Very_High  POINT (3.90889 7.44278)
# 3        51.0  235.4210   81.953151  Very_High  POINT (3.90917 7.44278)
# 4        15.0  234.4346   85.866027  Very_High  POINT (3.90944 7.44278)
# ...       ...       ...         ...        ...                      ...
# 144396    1.0  211.7292   63.087945        Low  POINT (3.86417 7.31167)
# 144397    0.0  220.4144   60.489041   Moderate  POINT (3.86444 7.31167)
# 144398    0.0  216.3101   62.886849        Low  POINT (3.86472 7.31167)
# 144399    0.0  214.3301   66.044932        Low  POINT (3.85972 7.31139)
# 144400    0.0  211.5915  101.515616        Low     POINT (3.86 7.31139)
#
# [144401 rows x 11 columns]>
#                    X              Y         Slope    Curvature         Aspect  \
# count  144401.000000  144401.000000  1.441190e+05  1.444010e+05  1.444010e+05
# mean        3.891534       7.374551 -2.502788e+35 -8.342043e+35 -1.673122e+35
# std         0.027887       0.032459  9.225150e+36  1.682769e+37  7.543591e+36
# min         3.831111       7.311389 -3.402823e+38 -3.402823e+38 -3.402823e+38
# 25%         3.868889       7.348333  5.105756e+01 -2.592000e+09  1.013099e+02
# 50%         3.891667       7.374167  6.198023e+01  0.000000e+00  1.894623e+02
# 75%         3.913611       7.400278  6.916712e+01  2.592000e+09  2.700000e+02
# max         3.954444       7.443056  8.657541e+01  3.888000e+10  3.591449e+02
#
#                 TWI            FA       Drainage       Rainfall
# count  1.444010e+05  1.444010e+05  144401.000000  144401.000000
# mean  -2.120858e+34 -2.120858e+35     219.714542      74.786932
# std    2.686356e+36  8.492619e+36       7.057921       8.891617
# min   -3.402823e+38 -3.402823e+38     203.729300      59.541096
# 25%   -8.654586e+00  0.000000e+00     214.286900      68.140822
# 50%   -8.006991e+00  1.000000e+00     220.631300      73.873425
# 75%   -6.709276e+00  6.000000e+00     224.191400      81.329315
# max    1.168344e+01  4.579360e+05     235.421000     101.515616
# Jumlah titik per kategori Susceptibility:
# SUSCEP
# Moderate     38116
# High         34451
# Low          32252
# Very_High    23456
# No_Flood     16126
# Name: count, dtype: int64
# C:\Users\ojiar\AppData\Local\Temp\ipykernel_54572\3154177768.py:49: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df_banjir, x='SUSCEP', palette='viridis')
